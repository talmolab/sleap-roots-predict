# %%
from sleap_roots_predict import process_experiment

import datetime

from pathlib import Path

# %%
# experiment parameters
EXPERIMENT_FOLDER_PATH = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/circumnutation/20250819_Suyash_Patil_CMTN_Kitx_vs_Hk1-3_07-30-25"
OUTPUT_BASE_DIR = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/circumnutation/20250819_Suyash_Patil_CMTN_Kitx_vs_Hk1-3_07-30-25"
EXPERIMENT_NAME = "20250819_Suyash_Patil_CMTN_Kitx_vs_Hk1-3_07-30-25"
METADATA_CSV = "//multilab-na.ad.salk.edu/hpi_dev/users/eberrigan/circumnutation/20250819_Suyash_Patil_CMTN_Kitx_vs_Hk1-3_07-30-25/CMTN_KITXvsHK1-3_META.csv"
GREYSCALE = True
IMAGE_PATTERN = "*.tif"
EXPECTED_SUFFIX_PATTERN = r"^\d{3}$"
MIN_IMAGES = 1
CHECK_DATE = True
CHECK_SUFFIX_CONSISTENCY = True
DRY_RUN = False  # set to False to actually run processing

# %%
datetime_str = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
run_folder = Path(OUTPUT_BASE_DIR) / "runs" / f"run_{datetime_str}"
log_file_path = run_folder / "log.txt"

# %%
process_experiment(
    base_dir=EXPERIMENT_FOLDER_PATH,
    output_dir=run_folder,
    experiment_name=EXPERIMENT_NAME,
    metadata_csv=METADATA_CSV,
    greyscale=GREYSCALE,
    image_pattern=IMAGE_PATTERN,
    expected_suffix_pattern=EXPECTED_SUFFIX_PATTERN,
    min_images=MIN_IMAGES,
    check_datetime=CHECK_DATE,
    check_suffix_consistency=CHECK_SUFFIX_CONSISTENCY,
    dry_run=DRY_RUN,
    log_file=log_file_path
)
# Out:
# INFO:sleap_roots_predict.video_utils:============================================================
# INFO:sleap_roots_predict.video_utils:Starting experiment: 20250819_Suyash_Patil_CMTN_Kitx_vs_Hk1-3_07-30-25
# INFO:sleap_roots_predict.video_utils:Base directory: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\circumnutation\20250819_Suyash_Patil_CMTN_Kitx_vs_Hk1-3_07-30-25
# INFO:sleap_roots_predict.video_utils:Metadata CSV: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\circumnutation\20250819_Suyash_Patil_CMTN_Kitx_vs_Hk1-3_07-30-25\CMTN_KITXvsHK1-3_META.csv
# INFO:sleap_roots_predict.video_utils:Output directory: \\multilab-na.ad.salk.edu\hpi_dev\users\eberrigan\circumnutation\20250819_Suyash_Patil_CMTN_Kitx_vs_Hk1-3_07-30-25\runs\run_20250827_091833
# INFO:sleap_roots_predict.video_utils:Processing mode: FULL PROCESSING
# INFO:sleap_roots_predict.video_utils:Greyscale conversion: True
# INFO:sleap_roots_predict.video_utils:Image pattern: *.tif
# ...
